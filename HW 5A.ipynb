# %%
#HW5A.2. Gear train angular velocity
import numpy as np

import numpy as np

r1 = 8
r2 = 6
r3 = 5
omega3z = -5

v=omega3z*r3
omega=v/r1
print(omega)

# %%
#HW5A.3. Center of mass of a point mass pair, graphical
#画图
m1=15
m2=10
k=m2/(m1+m2)
print("在m1和m2连线上从m1出发的",k)

# %%
#HW5A.4. Mass of an algebraic shape
import numpy as np
from sympy import *

x, y = symbols('x, y')

rho = 8
y1 = x**2 - 4*x - 13
y2 = -2*x**2 - 8*x + 1
x1 = -2
x2 = 0

y3=y2-y1
a=y3.integrate((x,x1,x2))
m=a*rho
print(m.evalf())

# %%
#HW5A.5. Relative magnitudes on a gear train

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#HW5A.6. Gear train point acceleration
import numpy as np

r1 = 7
r2 = 5
r3 = 9
r4 = 7
aPMag = 107
alpha3Mag = 8

#绕定轴转动的点，加速度由切向和法向分量组成

alpha2Mag=alpha3Mag*r3/r2
at=r2*alpha2Mag
an=(aPMag**2-at**2)**0.5
#an=r*w**2
w2=(an/r2)**0.5
v=w2*r2
w4=v/r4
print(w4)

#变式太多了QAQ，没有通解
